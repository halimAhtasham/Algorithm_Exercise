# %% [markdown]
# <a href="https://colab.research.google.com/github/halimAhtasham/Algorithm_Exercise/blob/main/titanic_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_path = "/content/drive/MyDrive/Datasets/Titanic-Dataset.csv"
df = pd.read_csv(data_path)
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pip install dtale

# %%
pip install plotly kaleido

# %%
import dtale
dtale.show(df)
# Out:
# http://403483bfbb4f:40000/dtale/main/1

# %%
pip install --upgrade plotly

# %% [markdown]
# Now that Plotly has been upgraded, let's try running D-tale again to ensure full compatibility.

# %%
import dtale
dtale.show(df)
# Out:
# http://403483bfbb4f:40000/dtale/main/2

# %%
pip install pyngrok

# %% [markdown]
# After installing `pyngrok`, we can now re-run D-tale with the `colab=True` parameter, which will set up a public tunnel using `ngrok` and provide a clickable link to access the D-tale interface.

# %%
import dtale
d = dtale.show(df, colab=True)
d.open_browser()

# %%
d.kill()
