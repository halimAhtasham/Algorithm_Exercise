# %% [markdown]
# <a href="https://colab.research.google.com/github/halimAhtasham/Algorithm_Exercise/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = int(input("Enter the Age: "))
y = int(input("Enter the BMI: "))
z = int(input("Enter the Glucose: "))
total = ((32-x)**2) + ((25-y)**2) + ((100-z)**2)
print(total)
print("Calculation done.........")
# Out:
# Enter the Age: 56
# Enter the BMI: 23
# Enter the Glucose: 120
# 980
# Calculation done.........
